# %% [markdown]
# # Finance Data Project
#
# This project involves exploratory data analysis of stock prices .I focus on analysing stock prices progress during the financial crisis to early 2016. The data was gotten from the link below:
#
# (https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308)

# %% [markdown]
# ### The Importations that would be used for the analysis

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## I will obtain data using pandas data reader to get information from the following banks
# Bank of America, CitiGroup, Goldman Sachs, JPMorgan Chase, Morgan Stanley, and Wells Fargo

# %% [markdown]
# ### The data began in 2006 till 2016

# %%
start = datetime.datetime(2006,1,1)
end = datetime.datetime(2016,1,1)

data = pd.read_pickle('all_banks (1)')

# %%
data = pd.read_pickle('all_banks (1)')
data.head()
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker           ...     MS                                  WFC         \
# Stock Info    Volume  ...   Open   High    Low  Close   Volume   Open   High
# Date                  ...
# 2006-01-03   1537660  ...  57.17  58.49  56.74  58.31  5377000  31.60  31.98
# 2006-01-04   1871020  ...  58.70  59.28  58.35  58.35  7977800  31.80  31.82
# 2006-01-05   1143160  ...  58.55  58.59  58.02  58.51  5778000  31.50  31.56
# ...

# %%
# Descriptive statistics

# %%
data.describe()
# Out:
# Bank Ticker          BAC                                                       \
# Stock Info          Open         High          Low        Close        Volume
# count        2517.000000  2517.000000  2517.000000  2517.000000  2.517000e+03
# mean           22.205217    22.479182    21.894076    22.174617  1.333590e+08
# std            15.308041    15.406193    15.197964    15.304852  1.274974e+08
# min             3.220000     3.510000     2.530000     3.140000  4.836000e+06
# 25%            12.310000    12.450000    12.130000    12.270000  4.845598e+07
# 50%            15.780000    15.970000    15.600000    15.790000  1.015867e+08
# 75%            32.730000    33.600000    31.750000    32.630000  1.752694e+08
# max            55.040000    55.080000    54.820000    54.900000  1.226791e+09
#
# Bank Ticker            C                                                       \
# Stock Info          Open         High          Low        Close        Volume
# ...

# %% [markdown]
# ### Creating a list and naming it stock_symbols

# %%
stock_symbols = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %%
#I will concatenate the bank dataframe to a single data frame named bank_stocks.

# %%
bank_stocks=pd.concat([BAC,C,GS,JPM,MS,WFC],axis=1,keys=stock_symbols)

# %%
bank_stocks
# Out:
#               BAC                                      C                  \
# Stock Info   Open   High    Low  Close    Volume    Open    High     Low
# Date
# 2006-01-03  46.92  47.18  46.15  47.08  16296700  490.00  493.80  481.10
# 2006-01-04  47.00  47.24  46.45  46.58  17757900  488.60  491.00  483.50
# 2006-01-05  46.58  46.83  46.32  46.64  14970900  484.40  487.80  484.00
# 2006-01-06  46.80  46.91  46.35  46.57  12599800  488.80  489.00  482.00
# 2006-01-09  46.72  46.97  46.36  46.60  15620000  486.00  487.40  483.00
# ...           ...    ...    ...    ...       ...     ...     ...     ...
# 2015-12-24  17.32  17.38  17.22  17.27  29373415   52.48   52.97   52.45
# 2015-12-28  17.22  17.23  16.98  17.13  41777497   52.57   52.57   51.96
# 2015-12-29  17.25  17.35  17.16  17.28  45670376   52.76   53.22   52.74
# 2015-12-30  17.20  17.24  17.04  17.05  35066378   52.84   52.94   52.25
# 2015-12-31  17.01  17.07  16.83  16.83  47152968   52.07   52.39   51.75
#
# ...

# %%
BAC = data['BAC']
C = data['C']
GS = data['GS']
JPM = data['JPM']
MS = data['MS']
WFC = data['WFC']

# %% [markdown]
# ##I then Set the column name levels

# %%
bank_stocks.columns.names = ['Bank_ticker','Stock Info']

# %% [markdown]
# ### Checking the head of the bank_stocks dataframe.

# %%
bank_stocks.head()
# Out:
# Bank_ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank_ticker           ...     MS                                  WFC         \
# Stock Info    Volume  ...   Open   High    Low  Close   Volume   Open   High
# Date                  ...
# 2006-01-03   1537660  ...  57.17  58.49  56.74  58.31  5377000  31.60  31.98
# 2006-01-04   1871020  ...  58.70  59.28  58.35  58.35  7977800  31.80  31.82
# 2006-01-05   1143160  ...  58.55  58.59  58.02  58.51  5778000  31.50  31.56
# ...

# %% [markdown]
# ## Exploratory Data Analysis
# #### What is the max Close price for each bank's stock throughout the time period?

# %%
bank_stocks.xs(axis=1,key='Close',level='Stock Info' ).max()
# Out:
# Bank_ticker
# BAC     54.90
# C      564.10
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     58.52
# dtype: float64

# %%
# therefore, CitiGroup has the highest max close price.

# %% [markdown]
# ** Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns = pd.DataFrame()

# %%
for tick in stock_symbols:
    returns[tick + 'Return'] = bank_stocks[tick]['Close'].pct_change()
    
    bank_stocks.head()

# %%
returns.head()
# Out:
#             BACReturn   CReturn  GSReturn  JPMReturn  MSReturn  WFCReturn
# Date
# 2006-01-03        NaN       NaN       NaN        NaN       NaN        NaN
# 2006-01-04  -0.010620 -0.018462 -0.013812  -0.014183  0.000686  -0.011599
# 2006-01-05   0.001288  0.004961 -0.000393   0.003029  0.002742  -0.000951
# 2006-01-06  -0.001501  0.000000  0.014169   0.007046  0.001025   0.005714
# 2006-01-09   0.000644 -0.004731  0.012030   0.016242  0.010586   0.000000

# %% [markdown]
# ### I will Create a pairplot using seaborn of the returns dataframe.

# %%
import seaborn as sns
sns.pairplot(returns[1:])

# %% [markdown]
# #### I want to figure out on what dates each bank stock had the best and worst single day returns,using this returns DataFrame.

# %%
returns.idxmin() #for worst days
# Out:
# BACReturn   2009-01-20
# CReturn     2011-05-06
# GSReturn    2009-01-20
# JPMReturn   2009-01-20
# MSReturn    2008-10-09
# WFCReturn   2009-01-20
# dtype: datetime64[ns]

# %%
returns.idxmax() #for best days
# Out:
# BACReturn   2009-04-09
# CReturn     2011-05-09
# GSReturn    2008-11-24
# JPMReturn   2009-01-21
# MSReturn    2008-10-13
# WFCReturn   2008-07-16
# dtype: datetime64[ns]

# %%
# I noticed that CitiGroup biggest drop and biggest gains days were so close to each other

# %% [markdown]
# ## Standard deviation of the returns

# %%
returns.std()
returns['2015-01-01':'2015-12-31'].std()
#
# Out:
# BACReturn    0.016163
# CReturn      0.015289
# GSReturn     0.014046
# JPMReturn    0.014017
# MSReturn     0.016249
# WFCReturn    0.012591
# dtype: float64

# %%
returns.loc['2015-01-01':'2015-12-31'].std()
# Out:
# BACReturn    0.016163
# CReturn      0.015289
# GSReturn     0.014046
# JPMReturn    0.014017
# MSReturn     0.016249
# WFCReturn    0.012591
# dtype: float64

# %% [markdown]
# ## creating a distplot using seaborn of the 2015 returns for Morgan Stanley

# %%
sns.distplot(returns.loc['2015-01-01':'2015-12-31']['MSReturn'],color='green',bins=60)
# Out:
# <AxesSubplot:xlabel='MSReturn', ylabel='Density'>

# %% [markdown]
# ** Create a distplot using seaborn of the 2008 returns for CitiGroup **

# %%
sns.displot(returns.loc['2008-01-01':'2008-12-31']['CReturn'],color='green', bins= 100,kde = True)

# %% [markdown]
# ____
# # More Visualization
#
# A lot of this project will focus on visualizations. Feel free to use any of your preferred visualization libraries to try to recreate the described plots below, seaborn, matplotlib, plotly and cufflinks, or just pandas.
#
# ### Imports

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(figsize=(10,4),label=tick)
    plt.legend()

# %% [markdown]
# ** Create a line plot showing Close price for each bank for the entire index of time. (Hint: Try using a for loop, or use [.xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html) to get a cross section of the data.)**

# %%
for tick in tickers:
    bank_stocks[tick]['Close'].plot(figsize=(10,4),label=tick)
    plt.legend()

# %%
bank_stocks.xs(level='Stock Info', key= 'Close', axis=1).plot(figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bank_stocks.xs(level='Stock Info', key= 'Close', axis=1).iplot()
# Out:
# <div>                            <div id="75ec0cb9-071e-44c1-9e4e-830701b54f3c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## Moving Averages
#
# Let's analyze the moving averages for these stocks in the year 2008.
#
# ** Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**

# %% [markdown]
# ** Create a heatmap of the correlation between the stocks Close Price.**

# %%
plt.figure(figsize=(12,6))
BAC['Close'].loc['2008-01-01':'2009-01-01'].rolling(window=30).mean().plot(label='30 Day Avg')
BAC['Close'].loc['2008-01-01':'2009-01-01'].plot(label='BAC CLOSE')
plt.legend()

# %%
sns.heatmap(bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr(),annot=True)
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %% [markdown]
# ** Optional: Use seaborn's clustermap to cluster the correlations together:**

# %%
sns.clustermap(bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr(),annot=True)

# %%
close_corr=bank_stocks.xs(key='Close', axis=1, level='Stock Info').corr()
close_corr
# Out:
# Bank Ticker       BAC         C        GS       JPM        MS       WFC
# Bank Ticker
# BAC          1.000000  0.971514  0.550950  0.103896  0.944219  0.008567
# C            0.971514  1.000000  0.434171  0.003540  0.933605 -0.068441
# GS           0.550950  0.434171  1.000000  0.685280  0.683834  0.499901
# JPM          0.103896  0.003540  0.685280  1.000000  0.250441  0.940279
# MS           0.944219  0.933605  0.683834  0.250441  1.000000  0.131864
# WFC          0.008567 -0.068441  0.499901  0.940279  0.131864  1.000000

# %%
close_corr.iplot(kind='heatmap')
# Out:
# <div>                            <div id="4ce63840-f815-4811-bd92-9a2f0364710d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Part 2 (Optional)
#
# In this second part of the project we will rely on the cufflinks library to create some Technical Analysis plots. This part of the project is experimental due to its heavy reliance on the cuffinks project, so feel free to skip it if any functionality is broken in the future.

# %% [markdown]
# ** Use .iplot(kind='candle) to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016.**

# %%
bac15= BAC[['Open', 'High', 'Low', 'Close']].loc['2015-01-01':'2016-01-01']
bac15.iplot(kind='candle')
# Out:
# <div>                            <div id="2e927bc9-4cc1-4431-b90a-5f9a02bf9726" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ** Use .ta_plot(study='sma') to create a Simple Moving Averages plot of Morgan Stanley for the year 2015.**

# %%
MS['Close'].loc['2015-01-01':'2016-01-01'].ta_plot(study='',periods=[13,21,55])
# Out:
# <div>                            <div id="2ea895da-537f-4808-a7c2-5f7fb8c715da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# **Use .ta_plot(study='boll') to create a Bollinger Band Plot for Bank of America for the year 2015.**

# %%
MS['Close'].loc['2015-01-01':'2016-01-01'].ta_plot(study='boll',periods=[13,21,55])
# Out:
# <div>                            <div id="890ba93b-5edb-446e-bc4b-a7c24b334a48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Great Job!
#
# Definitely a lot of more specific finance topics here, so don't worry if you didn't understand them all! The only thing you should be concerned with understanding are the basic pandas and visualization oeprations.
