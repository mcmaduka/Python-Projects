# %% [markdown]
# ## FIFA 21 DATA ANALYSIS IN PYTHON
# ## Exploratory Analysis and Visualization of FIFA 21 data set
# #### This is a dataset which contains information about players in FIFA 21. Dataset was a challenge exposed on twitter to be carried out by data analytics professionals, enthusiast as well as Learners. I first had to clean the data set using excel befire importing it to jupyter botebook to explore and visualize with python with the best of my abilities.
# #### Numpy, pandas, matplotlib, seaborn were mainly used in this project

# %% [markdown]
# ### I started by importing numpy,pandas, matplotlib and seaborn and then importing the dataset from the excel file in my system.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
data = pd.read_csv(r"C:\Users\HP\Documents\FIFA 21 DATA CLEANING PROJECT.csv", low_memory =False)

# %%
data
# Out:
#            ID               Name                              Long Name  \
# 0      158023           L. Messi                       LIONEL   MESSI
# 1       20801  Cristiano Ronaldo  C   RONALDO   DOS   SANTOS   AVEIRO
# 2      200389           J. Oblak                          JAN   OBLAK
# 3      192985       K. De Bruyne                  KEVIN   DE   BRUYNE
# 4      190871          Neymar Jr    NEYMAR   DA   SILVA   SANTOS   JR
# ...       ...                ...                                    ...
# 18974  247223                NaN                             AO   XIA
# 18975  258760                NaN                          BEN   HOUGH
# 18976  252757                NaN                     RONAN   MCKINLEY
# 18977  243790                NaN                        ZHENAO   WANG
# 18978  252520                NaN                          XIAO   ZHOU
#
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# ...

# %% [markdown]
# ### Top 15 players in FIFA 21
#
# ### since the data is already arranged based on their rating in descending order. I decided to use head. i.e data.head(15) to bring the top 15 players.

# %%
data.head(15)
# Out:
#         ID               Name                                  Long Name  \
# 0   158023           L. Messi                           LIONEL   MESSI
# 1    20801  Cristiano Ronaldo      C   RONALDO   DOS   SANTOS   AVEIRO
# 2   200389           J. Oblak                              JAN   OBLAK
# 3   192985       K. De Bruyne                      KEVIN   DE   BRUYNE
# 4   190871          Neymar Jr        NEYMAR   DA   SILVA   SANTOS   JR
# 5   188545     R. Lewandowski                     ROBERT   LEWANDOWSKI
# 6   209331           M. Salah                          MOHAMED   SALAH
# 7   212831            Alisson                ALISSON   RAMSES   BECKER
# 8   231747          K. Mbappe                          KYLIAN   MBAPPE
# 9   192448      M. ter Stegen              MARC   ANDRE   TER   STEGEN
# 10  203376        V. van Dijk                      VIRGIL   VAN   DIJK
# 11  208722            S. Mane                             SADIO   MANE
# ...

# %% [markdown]
# ## Descriptive statistics

# %%
data.describe()
# Out:
#                   ID           Age       OVERALL           POT  Height in cm  \
# count   18979.000000  18979.000000  18979.000000  18979.000000  18979.000000
# mean   226403.384794     25.194109     65.718636     71.136414    181.173402
# std     27141.054157      4.710520      6.968999      6.114635      6.891081
# min        41.000000     16.000000     47.000000     47.000000    152.000000
# 25%    210135.000000     21.000000     61.000000     67.000000    176.000000
# 50%    232418.000000     25.000000     66.000000     71.000000    181.000000
# 75%    246922.500000     29.000000     70.000000     75.000000    186.000000
# max    259216.000000     53.000000     93.000000     95.000000    206.000000
#
#        Weight in cm           BOV     Attacking      Crossing     Finishing  \
# count  18979.000000  18979.000000  18979.000000  18979.000000  18979.000000
# mean      75.019101     66.751726    248.938142     49.688392     45.842405
# ...

# %% [markdown]
# #### ID: there are 18979 players in the dataset.
# #### Age: the mean age of the players is 25 yrs old. Standard deviation is 4.71 meaning, the ages of the players are closer to the mean age and the ages are not highly spread or variated.  The oldset player is 53 yrs old, the youngest player is 16 yrs old.
# #### Overall: the highest rating of a player is 93% while the lowest rating is 47%.
# #### Height in cm: An average player is 181.173 cm tall.
# #### Weight in kg: An average player weighs 75 kg.

# %% [markdown]
# ## Top 20 players and their Clubs

# %%
data[['Long Name','OVERALL','Club']].sort_values(ascending= False, by = 'OVERALL').head(15)
# Out:
#                                     Long Name  OVERALL  \
# 0                            LIONEL   MESSI         93
# 1       C   RONALDO   DOS   SANTOS   AVEIRO         92
# 2                               JAN   OBLAK         91
# 3                       KEVIN   DE   BRUYNE         91
# 4         NEYMAR   DA   SILVA   SANTOS   JR         91
# 5                      ROBERT   LEWANDOWSKI         91
# 9               MARC   ANDRE   TER   STEGEN         90
# 10                      VIRGIL   VAN   DIJK         90
# 11                             SADIO   MANE         90
# 8                           KYLIAN   MBAPPE         90
# 7                 ALISSON   RAMSES   BECKER         90
# 6                           MOHAMED   SALAH         90
# 12  CARLOS   HENRIQUE   VENANCIO   CASIMIRO         89
# 13                       THIBAUT   COURTOIS         89
# 14                           MANUEL   NEUER         89
#
#                            Club
# 0          \n\n\n\nFC Barcelona
# ...

# %% [markdown]
# ### Therefore Lionel Messi is the best overall player according to FIFA 21 data. With C.Ronaldo coming in as 2nd best player.

# %%
x= data['Long Name'].head(15)
y= data['OVERALL'].head(15)

# %%
x,y
# Out:
# (0                              LIONEL   MESSI
#  1         C   RONALDO   DOS   SANTOS   AVEIRO
#  2                                 JAN   OBLAK
#  3                         KEVIN   DE   BRUYNE
#  4           NEYMAR   DA   SILVA   SANTOS   JR
#  5                        ROBERT   LEWANDOWSKI
#  6                             MOHAMED   SALAH
#  7                   ALISSON   RAMSES   BECKER
#  8                             KYLIAN   MBAPPE
#  9                 MARC   ANDRE   TER   STEGEN
#  10                        VIRGIL   VAN   DIJK
#  11                               SADIO   MANE
#  12    CARLOS   HENRIQUE   VENANCIO   CASIMIRO
#  13                         THIBAUT   COURTOIS
#  14                             MANUEL   NEUER
#  Name: Long Name, dtype: object,
#  0     93
#  1     92
#  2     91
#  3     91
#  4     91
#  5     91
#  6     90
#  7     90
#  8     90
#  9     90
#  10    90
#  11    90
#  12    89
#  13    89
#  14    89
#  Name: OVERALL, dtype: int64)

# %% [markdown]
# ## The basic information about the columns such as the data types

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 86 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Name              17918 non-null  object
#  2   Long Name         18979 non-null  object
#  3   photoUrl          18979 non-null  object
#  4   playerUrl         18979 non-null  object
#  5   Nationality       18979 non-null  object
#  6   Age               18979 non-null  int64
#  7   OVERALL           18979 non-null  int64
#  8   POT               18979 non-null  int64
#  9   Club              18979 non-null  object
#  10  Contract          18979 non-null  object
#  11  Positions         18979 non-null  object
#  12  Height in cm      18979 non-null  int64
#  13  Weight in cm      18979 non-null  float64
#  14  Preferred Foot    18979 non-null  object
#  15  BOV               18979 non-null  int64
# ...

# %% [markdown]
# ### the Information gotten here is:
# ### the dataset has 18979 rows and 86 columns which is quite large

# %% [markdown]
# ### Exploring dataset of players based on their ratings and positions

# %%
data[['Long Name','OVERALL','Best Position']].sort_values(ascending= False, by = 'OVERALL').head(15)
# Out:
#                                     Long Name  OVERALL Best Position
# 0                            LIONEL   MESSI         93            RW
# 1       C   RONALDO   DOS   SANTOS   AVEIRO         92            ST
# 2                               JAN   OBLAK         91            GK
# 3                       KEVIN   DE   BRUYNE         91           CAM
# 4         NEYMAR   DA   SILVA   SANTOS   JR         91            LW
# 5                      ROBERT   LEWANDOWSKI         91            ST
# 9               MARC   ANDRE   TER   STEGEN         90            GK
# 10                      VIRGIL   VAN   DIJK         90            CB
# 11                             SADIO   MANE         90            LW
# 8                           KYLIAN   MBAPPE         90            ST
# 7                 ALISSON   RAMSES   BECKER         90            GK
# 6                           MOHAMED   SALAH         90            RW
# 12  CARLOS   HENRIQUE   VENANCIO   CASIMIRO         89           CDM
# ...

# %% [markdown]
# ## How many positions are in the dataset?

# %%
data.Positions.unique()
# Out:
# array(['RW, ST, CF', 'ST, LW', 'GK', 'CAM, CM', 'LW, CAM', 'ST', 'RW',
#        'ST, LW, RW', 'CB', 'LW', 'CDM', 'CF, ST', 'LW, RW', 'CDM, CM',
#        'CDM, RB', 'CF, CAM', 'LW, ST', 'CM', 'ST, CF, LW', 'RM, LM, CAM',
#        'RB', 'RW, CAM, CM', 'LB', 'LM, CF', 'CF', 'RW, LW', 'CAM, RM, RW',
#        'CM, CDM', 'CAM, CF, ST', 'CM, CDM, CAM', 'CF, LW, CAM',
#        'CAM, RM, CF', 'LM, ST', 'RM, LM, RW', 'LM', 'CAM, RW', 'CB, CDM',
#        'RW, RM', 'LW, CF', 'CM, RM, LM', 'LB, LM', 'CAM, CM, RM',
#        'CAM, CM, CF', 'CAM, CF', 'LM, RM, LW', 'LM, LB, CM', 'CM, LM, LB',
#        'RM, RW', 'RM, CM', 'CAM, CM, LW', 'CB, LB', 'RM, RB', 'ST, RW',
#        'LM, RW, LW', 'RB, LB', 'RB, RM', 'RM', 'LM, RM, CF', 'CAM, RM',
#        'RB, RWB', 'CDM, CB, CM', 'CAM, RM, ST', 'LM, LW, RM', 'CM, CAM',
#        'ST, RM, CF', 'LM, RM', 'RM, CF', 'LM, LWB', 'RW, RM, CF',
#        'RB, CM', 'LW, CAM, RW', 'CAM, LW, CM', 'CM, CAM, CDM',
# ...

# %%
data.Positions.nunique()
# Out:
# 640

# %% [markdown]
# ### According to the data, there are 640 different or unique combinations of positions that the players plays in.

# %% [markdown]
# ### Which Countries have the higest number of players?
# ### top 20 countries with the higest number of players.

# %%
Top_countries = data.Nationality.value_counts().head(20)

# %%
Top_countries
# Out:
# England                1705
# Germany                1195
# Spain                  1065
# France                 1003
# Argentina               943
# Brazil                  887
# Japan                   485
# Netherlands             438
# Italy                   387
# Sweden                  380
# United States           376
# China PR                364
# Mexico                  362
# Norway                  362
# Portugal                361
# Poland                  354
# Uruguay                 348
# Korea Republic          340
# Republic of Ireland     340
# Colombia                339
# Name: Nationality, dtype: int64

# %% [markdown]
# #### Therefore, according to the dataset, England has the highest number of players with 1,705 players, followed by Germany with 1,195 players and Spain with 1,065 players.

# %%
18979 - 1705
# Out:
# 17274

# %%
(1705/17274)*100
# Out:
# 9.870325344448304

# %% [markdown]
# ### 9.8% of the players are English players.

# %% [markdown]
# ### Using Bar plot to visualize the top countries  with the higest number of players

# %%
Top_countries = data.Nationality.value_counts().head(20)
plt.figure(figsize=(7,5))
plt.xticks(rotation=75)
plt.title("Top Countries")
sns.barplot(Top_countries.index, Top_countries);
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Checking for players in a particular country
# ### since I am a Nigerian, i want to check if there are Nigerian players and how many they are.
# ### i will check using this formular

# %%
for a in data.Nationality:
    if a == 'Nigeria':
        print("There are Nigerian Players in FIFA 21.")
        break
        
else:
    print("There are no Nigerian Players in FIFA 21")
# Out:
# There are Nigerian Players in FIFA 21.

# %%
nigeria_data = data[(data.Nationality == 'Nigeria')]

# %%
nigeria_data
# Out:
#            ID            Name                  Long Name  \
# 99     226790        W. Ndidi          WILFRED   NDIDI
# 536    232293  R. Malinovskyi         VICTOR   OSIMHEN
# 701    241771         Melendo       ANTHONY   NWAKAEME
# 897    172962       H. Wilson     VICTOR   MOSES/210005/
# 951    234045       A. Barnes         HENRY   ONYEKURU
# ...       ...             ...                        ...
# 17295  233048    Park Jae Woo     TOM   DELE   BASHIRU
# 17299  257624        Chen Wei          TUNDE   OWOLABI
# 17549  255693   J. Akanyirige       ANTHONY   UZODIMMA
# 17607  258890      Liu Ziming  FISAYO   DELE   BASHIRU
# 18325  238487             NaN          ODYSSEUS   ALFA
#
#                                                photoUrl  \
# 99     https://cdn.sofifa.com/players/226/790/21_60.png
# 536    https://cdn.sofifa.com/players/232/293/21_60.png
# 701    https://cdn.sofifa.com/players/241/771/21_60.png
# 897    https://cdn.sofifa.com/players/172/962/21_60.png
# ...

# %%
nigeria_data.Name.count()
# Out:
# 128

# %% [markdown]
# ### Therefore, there are 128 Nigerian players in FIFA 21.

# %% [markdown]
# ### Age distribution of players

# %%
Age_distribution = data.Age.value_counts()

# %%
Age_distribution
# Out:
# 23    1465
# 24    1426
# 22    1421
# 20    1408
# 21    1381
# 26    1287
# 28    1271
# 25    1239
# 27    1213
# 19    1076
# 29    1045
# 30     929
# 31     768
# 18     697
# 32     628
# 33     473
# 34     357
# 17     289
# 35     220
# 36     161
# 37      80
# 38      56
# 16      35
# 39      27
# 40      13
# 41       6
# 42       5
# 43       2
# 53       1
# Name: Age, dtype: int64

# %% [markdown]
# ### Visualizing the Age distribution using displot.

# %%
sns.set_style('whitegrid')
sns.displot(data['Age'], kde = False, color='red', bins = 60)

# %% [markdown]
# ### Visualizing the players based on their ratings using distplot

# %%
sns.set_style('dark')
sns.displot(data['OVERALL'],kde = False, bins = 100, color = 'green')

# %% [markdown]
# ### I Observed that the Overall Distribution is a normal distribution and most of the players ratings are between 60% to 70%

# %%
plt.figure(figsize=(7,8))

plt.xlabel('Age')
plt.ylabel('Number of players')

plt.hist(data.Age, bins = np.arange(15,50,5), color='orange')
# Out:
# (array([2097., 7101., 6055., 3155.,  544.,   26.]),
#  array([15, 20, 25, 30, 35, 40, 45]),
#  <BarContainer object of 6 artists>)

# %% [markdown]
# ### The maximum number of players in fifa 21 falls in the age group 20 to 25.

# %% [markdown]
# ### Exploring clubs in the dataset

# %%
number_of_clubs = data.Club.nunique()

# %%
number_of_clubs
# Out:
# 682

# %% [markdown]
# #### there are 682 clubs in fifa 21

# %% [markdown]
# ### How many players are in each clubs?

# %%
data.Club.value_counts().head(50).sort_values()
# Out:
# \n\n\n\nFC Nantes                    32
# \n\n\n\n1. FSV Mainz 05              32
# \n\n\n\nLazio                        32
# \n\n\n\nHellas Verona                32
# \n\n\n\nReal Sociedad                32
# \n\n\n\nAston Villa                  32
# \n\n\n\nVfL Wolfsburg                32
# \n\n\n\nWest Bromwich Albion         32
# \n\n\n\nUdinese                      32
# \n\n\n\nEverton                      33
# \n\n\n\nFulham                       33
# \n\n\n\nTottenham Hotspur            33
# \n\n\n\nVfB Stuttgart                33
# \n\n\n\nManchester City              33
# \n\n\n\nLiverpool                    33
# \n\n\n\nChelsea                      33
# \n\n\n\nManchester United            33
# \n\n\n\nArsenal                      33
# \n\n\n\nGranada CF                   33
# \n\n\n\nBorussia Mönchengladbach     33
# \n\n\n\nHertha BSC                   33
# \n\n\n\nCagliari                     33
# \n\n\n\nVillarreal CF                33
# ...

# %%
top_clubs = data.Club.value_counts().head(20)
plt.figure(figsize=(12,10))
plt.xticks(rotation=75)

plt.bar(top_clubs.index, top_clubs)
# Out:
# <BarContainer object of 20 artists>

# %% [markdown]
# ##### there are 682 clubs in FIFA 21. players with no clubs are 237.

# %%
data['Club'].describe()
# Out:
# count       18979
# unique        682
# top       No Club
# freq          237
# Name: Club, dtype: object
